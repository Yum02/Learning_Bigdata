# %% [markdown]
# 파일 저장

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3]
y = [2, 4, 8]

# %%
plt.plot(x, y)

plt.savefig('graph.png', dpi=100)

# %%
plt.figure(dpi=200)
plt.plot(x, y)
plt.savefig('graph_200.png', dpi=100)
