# %% [markdown]
# 2.축

# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3]
y = [2, 4, 8]

# %%
plt.plot(x, y)
plt.title('Line graph')
# Out:
# Text(0.5, 1.0, 'Line graph')

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %%
plt.plot(x,y)
plt.xlabel('X', color='red')
plt.ylabel('Y', color='#00aa00')
# Out:
# Text(0, 0.5, 'Y')

# %%
plt.plot(x,y)
plt.xlabel('X', color='red', loc='right')
plt.ylabel('Y', color='#00aa00', loc='top')
# Out:
# Text(0, 1, 'Y')

# %%
plt.plot(x, y)
plt.xticks([1, 2, 3])
plt.yticks([3, 6, 9, 12])
plt.show()
